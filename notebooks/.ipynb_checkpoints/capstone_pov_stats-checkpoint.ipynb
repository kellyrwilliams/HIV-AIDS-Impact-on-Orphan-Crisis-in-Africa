# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
# %matplotlib inline

# %%
pov_stats_csv = pd.read_csv('../data/Using/PovStatsData.csv')
pov_stats_csv.head(25)
# Out:
#            Country Name Country Code  \
# 0   East Asia & Pacific          EAS
# 1   East Asia & Pacific          EAS
# 2   East Asia & Pacific          EAS
# 3   East Asia & Pacific          EAS
# 4   East Asia & Pacific          EAS
# 5   East Asia & Pacific          EAS
# 6   East Asia & Pacific          EAS
# 7   East Asia & Pacific          EAS
# 8   East Asia & Pacific          EAS
# 9   East Asia & Pacific          EAS
# 10  East Asia & Pacific          EAS
# 11  East Asia & Pacific          EAS
# 12  East Asia & Pacific          EAS
# 13  East Asia & Pacific          EAS
# 14  East Asia & Pacific          EAS
# 15  East Asia & Pacific          EAS
# 16  East Asia & Pacific          EAS
# 17  East Asia & Pacific          EAS
# 18  East Asia & Pacific          EAS
# 19  East Asia & Pacific          EAS
# 20  East Asia & Pacific          EAS
# 21  East Asia & Pacific          EAS
# 22  East Asia & Pacific          EAS
# 23  East Asia & Pacific          EAS
# ...

# %%
pov_stats_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10730 entries, 0 to 10729
# Data columns (total 50 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    10730 non-null  object
#  1   Country Code    10730 non-null  object
#  2   Indicator Name  10730 non-null  object
#  3   Indicator Code  10730 non-null  object
#  4   1974            217 non-null    float64
#  5   1975            217 non-null    float64
#  6   1976            183 non-null    float64
#  7   1977            192 non-null    float64
#  8   1978            200 non-null    float64
#  9   1979            268 non-null    float64
#  10  1980            234 non-null    float64
#  11  1981            374 non-null    float64
#  12  1982            280 non-null    float64
#  13  1983            314 non-null    float64
#  14  1984            342 non-null    float64
#  15  1985            446 non-null    float64
#  16  1986            494 non-null    float64
# ...

# %%
pov_stats_rename = pov_stats_csv.rename(columns = {'Country Name': 'Country', 'Country Code': 'Code',})
pov_stats_rename.head()
# Out:
#                Country Code  \
# 0  East Asia & Pacific  EAS
# 1  East Asia & Pacific  EAS
# 2  East Asia & Pacific  EAS
# 3  East Asia & Pacific  EAS
# 4  East Asia & Pacific  EAS
#
#                                       Indicator Name     Indicator Code  1974  \
# 0  Annualized growth in per capita real survey me...     SI.SPR.PC40.ZG   NaN
# 1  Annualized growth in per capita real survey me...     SI.SPR.PT10.ZG   NaN
# 2  Annualized growth in per capita real survey me...     SI.SPR.PT60.ZG   NaN
# 3  Annualized growth in per capita real survey me...     SI.SPR.PCAP.ZG   NaN
# 4  Annualized growth in per capita real survey me...  SI.POV.XPND.MD.ZG   NaN
#
#    1975  1976  1977  1978  1979  ...  2010  2011  2012  2013  2014  2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
pov_stats_rename.isna().sum()
# Out:
# Country               0
# Code                  0
# Indicator Name        0
# Indicator Code        0
# 1974              10513
# 1975              10513
# 1976              10547
# 1977              10538
# 1978              10530
# 1979              10462
# 1980              10496
# 1981              10356
# 1982              10450
# 1983              10416
# 1984              10388
# 1985              10284
# 1986              10236
# 1987              10123
# 1988              10319
# 1989              10221
# 1990              10141
# 1991              10108
# 1992               9876
# 1993              10056
# 1994               9990
# 1995               9783
# 1996               9858
# 1997               9971
# 1998               9796
# 1999               9892
# 2000               9533
# 2001               9777
# 2002               9448
# 2003               9353
# 2004               9136
# 2005               8989
# 2006               9014
# 2007               9119
# ...

# %%
pov_stats_rename.shape
# Out:
# (10730, 50)

# %%
pov_stats_clean['Indicator Code'].value_counts()
# Out:
# SI.POV.RUGP.NC       185
# SI.POV.DDAY.65       185
# SI.POV.URGP.NC       185
# SI.DST.04TH.20       185
# SI.SPR.PT60          185
# SI.POV.NAHC          185
# SI.SPR.PT10.ZG       185
# SI.POV.DDAY.RU       185
# SI.DST.03RD.20       185
# SI.POV.GINI          185
# SI.POV.ELEC.MI       185
# SI.POV.DDAY.UR       185
# SI.POV.URHC.NC       185
# SI.DST.FRST.10       185
# SI.SPR.PT60.ZG       185
# SI.SPR.PC40.ZG       185
# SI.POV.DDAY.16.PL    185
# SI.POV.RUHC          185
# SI.POV.NOP1          185
# SI.POV.DDAY.16.SG    185
# SI.POV.DDAY.FE       185
# SI.DST.FRST.20       185
# SI.POV.UMIC.GP       185
# SI.SPR.PCAP          185
# SI.POV.DDAY.MI       185
# SI.POV.DDAY.MA       185
# SI.SPR.PC40          185
# SI.DST.10TH.10       185
# SI.POV.UMIC.NO       185
# SI.POV.NAGP.NC       185
# SI.POV.DDAY          185
# SI.POV.LMIC.GP       185
# SI.DST.02ND.20       185
# SI.POV.UMIC          185
# SI.POV.DDAY.16.PR    185
# SI.POV.DDAY.16.ST    185
# SI.POV.LMIC          185
# ...

# %%
pov_stats_clean = pov_stats_rename.drop(columns = ['Unnamed: 49', 'Indicator Code'])
pov_stats_clean.head()
# Out:
#                Country Code  \
# 0  East Asia & Pacific  EAS
# 1  East Asia & Pacific  EAS
# 2  East Asia & Pacific  EAS
# 3  East Asia & Pacific  EAS
# 4  East Asia & Pacific  EAS
#
#                                       Indicator Name  1974  1975  1976  1977  \
# 0  Annualized growth in per capita real survey me...   NaN   NaN   NaN   NaN
# 1  Annualized growth in per capita real survey me...   NaN   NaN   NaN   NaN
# 2  Annualized growth in per capita real survey me...   NaN   NaN   NaN   NaN
# 3  Annualized growth in per capita real survey me...   NaN   NaN   NaN   NaN
# 4  Annualized growth in per capita real survey me...   NaN   NaN   NaN   NaN
#
#    1978  1979  1980  ...  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
pov_stats_clean['Country'].value_counts()
# Out:
# Georgia                58
# Gambia, The            58
# East Asia & Pacific    58
# Lithuania              58
# Botswana               58
#                        ..
# Seychelles             58
# Gabon                  58
# Korea, Rep.            58
# Guinea                 58
# Norway                 58
# Name: Country, Length: 185, dtype: int64

# %%
pov_stats_clean['Indicator Name'].value_counts()
# Out:
# Multidimensional poverty, Drinking water (% of population deprived)                                                                                            185
# Poverty headcount ratio at national poverty lines (% of population)                                                                                            185
# Poverty headcount ratio at $1.90 a day, with primary education (2011 PPP) (% of population age 16+ with primary education)                                     185
# Median daily per capita income or consumption expenditure (2011 PPP)                                                                                           185
# Poverty headcount ratio at $1.90 a day, without education (2011 PPP) (% of population age 16+ without education)                                               185
# Income share held by highest 20%                                                                                                                               185
# ...
