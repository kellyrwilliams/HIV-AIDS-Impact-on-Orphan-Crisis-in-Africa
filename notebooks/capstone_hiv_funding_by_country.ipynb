# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
# %matplotlib inline

# %%
hiv_funding_csv = pd.read_csv('../data/Using/hivaids-funding-by-source.csv')
hiv_funding_csv.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2008
# 1  Afghanistan  AFG  2009
# 2  Afghanistan  AFG  2010
# 3  Afghanistan  AFG  2011
# 4  Afghanistan  AFG  2012
#
#    Country-reported HIV expenditure by funding source - Global Fund  \
# 0                                              0.000
# 1                                        1087983.000
# 2                                        1774255.000
# 3                                        1645559.550
# 4                                        1829829.153
#
#    Country-reported HIV expenditure by funding source - Domestic Public  \
# 0                                           129260.0
# 1                                           132200.0
# 2                                           200000.0
# 3                                                0.0
# 4                                            24250.0
#
#    Country-reported HIV expenditure by funding source - Domestic Private  \
# ...

# %%
hiv_funding_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 11 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Entity                                                                    954 non-null    object
#  1   Code                                                                      954 non-null    object
#  2   Year                                                                      954 non-null    int64
#  3   Country-reported HIV expenditure by funding source - Global Fund          929 non-null    float64
#  4   Country-reported HIV expenditure by funding source - Domestic Public      943 non-null    float64
#  5   Country-reported HIV expenditure by funding source - Domestic Private     935 non-null    float64
# ...

# %%
hiv_funding_csv.isna().sum()
# Out:
# Entity                                                                        0
# Code                                                                          0
# Year                                                                          0
# Country-reported HIV expenditure by funding source - Global Fund             25
# Country-reported HIV expenditure by funding source - Domestic Public         11
# Country-reported HIV expenditure by funding source - Domestic Private        19
# Country-reported HIV expenditure by funding source - International           14
# Country-reported HIV expenditure by funding source - Other bilaterals        24
# Country-reported HIV expenditure by funding source - Development Banks       29
# Country-reported HIV expenditure by funding source - Other multilaterals     20
# Country-reported HIV expenditure by funding source - PEPFAR                 669
# dtype: int64

# %%
hiv_funding_csv.fillna(0).head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2008
# 1  Afghanistan  AFG  2009
# 2  Afghanistan  AFG  2010
# 3  Afghanistan  AFG  2011
# 4  Afghanistan  AFG  2012
#
#    Country-reported HIV expenditure by funding source - Global Fund  \
# 0                                              0.000
# 1                                        1087983.000
# 2                                        1774255.000
# 3                                        1645559.550
# 4                                        1829829.153
#
#    Country-reported HIV expenditure by funding source - Domestic Public  \
# 0                                           129260.0
# 1                                           132200.0
# 2                                           200000.0
# 3                                                0.0
# 4                                            24250.0
#
#    Country-reported HIV expenditure by funding source - Domestic Private  \
# ...

# %%
hiv_funding_csv.dtypes
# Out:
# Entity                                                                       object
# Code                                                                         object
# Year                                                                          int64
# Country-reported HIV expenditure by funding source - Global Fund            float64
# Country-reported HIV expenditure by funding source - Domestic Public        float64
# Country-reported HIV expenditure by funding source - Domestic Private       float64
# Country-reported HIV expenditure by funding source - International          float64
# Country-reported HIV expenditure by funding source - Other bilaterals       float64
# Country-reported HIV expenditure by funding source - Development Banks      float64
# Country-reported HIV expenditure by funding source - Other multilaterals    float64
# Country-reported HIV expenditure by funding source - PEPFAR                 float64
# dtype: object

# %%
hiv_funding_csv = hiv_funding_csv.rename(columns = {'Entity': 'Country', 'Country-reported HIV expenditure by funding source - Global Fund': 'Global Fund',\
                                                   'Country-reported HIV expenditure by funding source - Domestic Public': 'Domestic Public',\
                                                    'Country-reported HIV expenditure by funding source - Domestic Private': 'Domestic Private',\
                                                   'Country-reported HIV expenditure by funding source - International': 'International',\
                                                   'Country-reported HIV expenditure by funding source - Other bilaterals': 'Other Bilaterals',\
                                                   'Country-reported HIV expenditure by funding source - Development Banks': 'Development Banks',\
                                                   'Country-reported HIV expenditure by funding source - Other multilaterals': 'Other multilaterals',\
                                                   'Country-reported HIV expenditure by funding source - PEPFAR': 'PEPFAR'})
hiv_funding_csv.head()
# Out:
#        Country Code  Year  Global Fund  Domestic Public  Domestic Private  \
# 0  Afghanistan  AFG  2008        0.000         129260.0               0.0
# 1  Afghanistan  AFG  2009  1087983.000         132200.0               0.0
# 2  Afghanistan  AFG  2010  1774255.000         200000.0               0.0
# 3  Afghanistan  AFG  2011  1645559.550              0.0               0.0
# 4  Afghanistan  AFG  2012  1829829.153          24250.0               0.0
#
#    International  Other Bilaterals  Development Banks  Other multilaterals  \
# 0     3112158.00          254053.0          2669283.0                  0.0
# 1     5026352.00          282525.0          3220281.0                  0.0
# 2     4237825.00           90499.0          1523129.0                  0.0
# 3     8002073.55         1456111.0          3728220.0                  0.0
# 4     9028297.00               0.0          2080691.5                  0.0
#
#    PEPFAR
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
hiv_funding = hiv_funding_csv

# %%
hiv_funding_csv.to_csv('../data/cleaned_data/hiv_funding.csv')
